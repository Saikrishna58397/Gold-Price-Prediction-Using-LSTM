# %% [markdown]
# # Step 1: Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
import tensorflow as tf
from keras import Model
from keras.layers import Input, Dense, Dropout
from keras.layers import LSTM

# %% [markdown]
# # Step 2: Reading Dataset

# %%
df = pd.read_csv('/content/Gold Price (2013-2023).csv')

# %% [markdown]
# # Step 3: Dataset Overview

# %%
df
# Out:
#             Date     Price      Open      High       Low     Vol. Change %
# 0     12/30/2022  1,826.20  1,821.80  1,832.40  1,819.80  107.50K    0.01%
# 1     12/29/2022  1,826.00  1,812.30  1,827.30  1,811.20  105.99K    0.56%
# 2     12/28/2022  1,815.80  1,822.40  1,822.80  1,804.20  118.08K   -0.40%
# 3     12/27/2022  1,823.10  1,808.20  1,841.90  1,808.00  159.62K    0.74%
# 4     12/26/2022  1,809.70  1,805.80  1,811.95  1,805.55      NaN    0.30%
# ...          ...       ...       ...       ...       ...      ...      ...
# 2578  01/08/2013  1,663.20  1,651.50  1,662.60  1,648.80    0.13K    0.97%
# 2579  01/07/2013  1,647.20  1,657.30  1,663.80  1,645.30    0.09K   -0.16%
# 2580  01/04/2013  1,649.90  1,664.40  1,664.40  1,630.00    0.31K   -1.53%
# 2581  01/03/2013  1,675.60  1,688.00  1,689.30  1,664.30    0.19K   -0.85%
# 2582  01/02/2013  1,689.90  1,675.80  1,695.00  1,672.10    0.06K    0.78%
#
# [2583 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2583 entries, 0 to 2582
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2583 non-null   object
#  1   Price     2583 non-null   object
#  2   Open      2583 non-null   object
#  3   High      2583 non-null   object
#  4   Low       2583 non-null   object
#  5   Vol.      2578 non-null   object
#  6   Change %  2583 non-null   object
# dtypes: object(7)
# memory usage: 141.4+ KB

# %% [markdown]
# # Step 4: Data Preparation

# %%
df.drop(['Vol.', 'Change %'], axis=1, inplace=True)

# %% [markdown]
# ## Step 4.2: Transforming Data

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by='Date', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
NumCols = df.columns.drop(['Date'])
df[NumCols] = df[NumCols].replace({',': ''}, regex=True)
df[NumCols] = df[NumCols].astype('float64')

# %%
df.head()
# Out:
#         Date   Price    Open    High     Low
# 0 2013-01-02  1689.9  1675.8  1695.0  1672.1
# 1 2013-01-03  1675.6  1688.0  1689.3  1664.3
# 2 2013-01-04  1649.9  1664.4  1664.4  1630.0
# 3 2013-01-07  1647.2  1657.3  1663.8  1645.3
# 4 2013-01-08  1663.2  1651.5  1662.6  1648.8

# %% [markdown]
# ## Step 4.3: Checking Duplicates
# __There are no duplicate samples in Date feature:__

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Step 4.4: Checking Missing Values
# __There are no missing values in the dataset:__

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Step 5: Visualizing Gold Price History Data
#
# __Interactive Gold Price Chart:__

# %%
fig = px.line(y=df.Price, x=df.Date)
fig.update_traces(line_color='black')
fig.update_layout(xaxis_title="Date",
                  yaxis_title="Scaled Price",
                  title={'text': "Gold Price History Data", 'y':0.95, 'x':0.5, 'xanchor':'center', 'yanchor':'top'},
                  plot_bgcolor='rgba(255,223,0,0.8)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="15770154-e196-4ec3-b76b-9a61ab84f480" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15770154-e196-4ec3-b76b-9a61ab84f480")) {                    Plotly.newPlot(                        "15770154-e196-4ec3-b76b-9a61ab84f480",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"black","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-03T00:00:00","2013-06-04T00:00:00","2013-06-05T00:00:00","2013-06-06T00:00:00","2013-06-07T00:00:00","2013-06-10T00:00:00","2013-06-11T00:00:00","2013-06-12T00:00:00","2013-06-13T00:00:00","2013-06-14T00:00:00","2013-06-17T00:00:00","2013-06-18T00:00:00","2013-06-19T00:00:00","2013-06-20T00:00:00","2013-06-21T00:00:00","2013-06-24T00:00:00","2013-06-25T00:00:00","2013-06-26T00:00:00","2013-06-27T00:00:00","2013-06-28T00:00:00","2013-07-01T00:00:00","2013-07-02T00:00:00","2013-07-03T00:00:00","2013-07-04T00:00:00","2013-07-05T00:00:00","2013-07-08T00:00:00","2013-07-09T00:00:00","2013-07-10T00:00:00","2013-07-11T00:00:00","2013-07-12T00:00:00","2013-07-15T00:00:00","2013-07-16T00:00:00","2013-07-17T00:00:00","2013-07-18T00:00:00","2013-07-19T00:00:00","2013-07-22T00:00:00","2013-07-23T00:00:00","2013-07-24T00:00:00","2013-07-25T00:00:00","20 ...

# %% [markdown]
# # Step 6: Splitting Data to Training & Test Sets

# %%
test_size = df[df.Date.dt.year==2022].shape[0]
test_size
# Out:
# 260

# %% [markdown]
# __Gold Price Training and Test Sets Plot:__

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'yellow'
plt.rc('axes',edgecolor='white')
plt.plot(df.Date[:-test_size], df.Price[:-test_size], color='black', lw=2)
plt.plot(df.Date[-test_size:], df.Price[-test_size:], color='blue', lw=2)
plt.title('Gold Price Training and Test Sets', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training set', 'Test set'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %% [markdown]
# # Step 7: Data Scaling
# __Since we aim to predict Price only based on its historical data, we scale Price using MinMaxScaler to avoid intensive computations:__

# %%
scaler = MinMaxScaler()
scaler.fit(df.Price.values.reshape(-1,1))
# Out:
# MinMaxScaler()

# %%
 window_size = 60

# %% [markdown]
# __Training Set:__

# %%
train_data = df.Price[:-test_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

# %%
X_train = []
y_train = []

for i in range(window_size, len(train_data)):
    X_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %% [markdown]
# __Test Set:__

# %%
test_data = df.Price[-test_size-60:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

# %%
X_test = []
y_test = []

for i in range(window_size, len(test_data)):
    X_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])

# %% [markdown]
# # Step 9: Converting Data to Numpy Arrays

# %%
X_train = np.array(X_train)
X_test  = np.array(X_test)
y_train = np.array(y_train)
y_test  = np.array(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test  = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
print('X_train Shape: ', X_train.shape)
print('y_train Shape: ', y_train.shape)
print('X_test Shape:  ', X_test.shape)
print('y_test Shape:  ', y_test.shape)
# Out:
# X_train Shape:  (2263, 60, 1)
# y_train Shape:  (2263, 1)
# X_test Shape:   (260, 60, 1)
# y_test Shape:   (260, 1)

# %% [markdown]
# # Step 10: Creating an LSTM Network

# %% [markdown]
# __Model Definition:__

# %%
def define_model():
    input1 = Input(shape=(window_size,1))
    x = LSTM(units = 64, return_sequences=True)(input1)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64, return_sequences=True)(x)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64)(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation='softmax')(x)
    dnn_output = Dense(1)(x)

    model = Model(inputs=input1, outputs=[dnn_output])
    model.compile(loss='mean_squared_error', optimizer='Nadam')
    model.summary()

    return model

# %% [markdown]
# __Model Training:__

# %%
model = define_model()
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None,
150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 103ms/step - loss: 3.2566e-04 - val_loss: 0.0020
# Epoch 126/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 105ms/step - loss: 3.0480e-04 - val_loss: 0.0011
# Epoch 127/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - loss: 3.1138e-04 - val_loss: 0.0018
# Epoch 128/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 3.0749e-04 - val_loss: 0.0014
# Epoch 129/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - loss: 3.0509e-04 - val_loss: 0.0011
# Epoch 130/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 3.1946e-04 - val_loss: 9.0904e-04
# Epoch 131/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - loss: 2.8946e-04 - val_loss: 7.4897e-04
# Epoch 132/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 102ms/step - loss: 3.1919e-04 - val_loss: 7.0060e-04
# Epoch 133/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - loss: 3.0068e-04 - val_loss: 8.5285e-04
# Epoch 134/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 103ms/step - loss: 3.0686e-04 - val_loss: 7.9315e-04
# Epoch 135/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 104ms/step - loss: 2.9390e-04 - val_loss: 6.6979e-04
# Epoch 136/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - loss: 3.2105e-04 - val_loss: 9.0760e-04
# Epoch 137/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - loss: 3.2005e-04 - val_loss: 7.1318e-04
# Epoch 138/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - loss: 3.0729e-04 - val_loss: 0.0012
# Epoch 139/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - loss: 3.0874e-04 - val_loss: 6.1139e-04
# Epoch 140/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - loss: 2.9063e-04 - val_loss: 8.3926e-04
# Epoch 141/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - loss: 3.0639e-04 - val_loss: 0.0011
# Epoch 142/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - loss: 3.0979e-04 - val_loss: 9.8997e-04
# Epoch 143/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - loss: 2.9586e-04 - val_loss: 0.0016
# Epoch 144/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - loss: 2.8964e-04 - val_loss: 0.0011
# Epoch 145/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - loss: 2.9294e-04 - val_loss: 8.5695e-04
# Epoch 146/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - loss: 3.0682e-04 - val_loss: 7.5153e-04
# Epoch 147/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - loss: 2.9910e-04 - val_loss: 0.0015
# Epoch 148/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - loss: 3.1213e-04 - val_loss: 0.0016
# Epoch 149/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - loss: 3.0323e-04 - val_loss: 8.7642e-04
# Epoch 150/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 104ms/step - loss: 3.0561e-04 - val_loss: 0.0012

# %% [markdown]
# # Step 11: Model Evaluation

# %%
result = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
Accuracy = 1 - MAPE

# %%
print("Test Loss:", result)
print("Test MAPE:", MAPE)
print("Test Accuracy:", Accuracy)
# Out:
# Test Loss: 0.0012042769230902195
# Test MAPE: 0.03841894609672128
# Test Accuracy: 0.9615810539032787

# %% [markdown]
# # Step 12: Visualizing Results

# %%
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred)

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'yellow'
plt.rc('axes',edgecolor='white')
plt.plot(df['Date'].iloc[:-test_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_true, color='blue', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_pred, color='red', lw=2)
plt.title('Model Performance on Gold Price Prediction', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training Data', 'Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()
